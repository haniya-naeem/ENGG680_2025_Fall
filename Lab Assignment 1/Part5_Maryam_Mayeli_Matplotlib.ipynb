# %% [markdown]
# <a href="https://colab.research.google.com/github/haniya-naeem/ENGG680_2025_Fall/blob/main/Lab%20Assignment%201/Part5_Maryam_Mayeli_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code and analysis by Maryam Mayeli (Part 5 - Matplotlib Section)
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['englishGrade'], bins=10, alpha=0.7, label='English Grades')
plt.xlable('Grade')
plt.ylable('Frequency')
plt.title('Distribution of English Grades')
plt.legend(loc='upper right')
plt.grid(True)
plt.savefig('hist_english.png')
plt.show

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['mathGrade'], bins=10, alpha=0.7, lable='Math Grade')
plt.xlable('Grade')
plt.ylable('Frequency')
plt.title('Distribution of Math Grades')
plt.legend(loc='upper right')
plt.grid(True)
plt.savefig('hist_math.png')
plt.show

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_studentGrades['englishGrade'], df_studentGrades['mathGrade'])
plt.xlable('English Grade')
plt.ylable('Math Grade')
plt.title('English Grade vs Math Grade')
plt.grid(True)
plt.savefig('scatter_english_math.png')
plt.show

# %%
corr = df_studentGrades['englishGrade'].corr(df_studentGrades['mathGrade'])
print(f'Correlation (English vs Math): {corr:.2f}')

# Simple automatic interpretation text:
if corr >= 0.7:
    level = "strong positive"
elif corr >= 0.4:
    level = "moderate positive"
elif corr >= 0.2:
    level = "weak positive"
elif corr <= -0.7:
    level = "strong negative"
elif corr <= -0.4:
    level = "moderate negative"
elif corr <= -0.2:
    level = "weak negative"
else:
    level = "little to no"

print(f"Interpretation: There is a {level} relationship between English and Math grades.")
print("Visual check: points should generally rise from left-bottom to right-top if positive.")

# %% [markdown]
# ## Part 5 — Summary (Maryam)
#
# The histograms show English grades range 76–98 and Math 79–99.
# The scatter plot does not show a clear linear trend between the two subjects.
# The correlation between English and Math is approximately -0.04, indicating little to no relationship in this dataset.
